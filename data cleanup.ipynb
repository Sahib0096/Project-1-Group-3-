# %%
#importing the dataset

import pandas as pd
from pathlib import Path
df = pd.read_csv('./full data.csv')
            
df.head()
# Out:
#    REF_DATE     GEO           DGUID Statistics Characteristics  \
# 0      1999  Canada  2016A000011124      Value  All households
# 1      1999  Canada  2016A000011124      Value  All households
# 2      1999  Canada  2016A000011124      Value  All households
# 3      1999  Canada  2016A000011124      Value  All households
# 4      1999  Canada  2016A000011124      Value  All households
#
#   Income, consumption and savings      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0     Household disposable income  Dollars      81      millions          6
# 1       Compensation of employees  Dollars      81      millions          6
# 2                Net mixed income  Dollars      81      millions          6
# 3        Property income received  Dollars      81      millions          6
# 4      Less: property income paid  Dollars      81      millions          6
#
#        VECTOR COORDINATE     VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# ...

# %%
#Import columns - years, segments (income consumption and savings)

new_df = df.drop(columns = ['DGUID', 'Statistics' ,'UOM' ,'UOM_ID' , 'SCALAR_FACTOR' , 'SCALAR_ID', 'VECTOR' , 'COORDINATE' , 'STATUS' , 'SYMBOL','TERMINATED', 'DECIMALS'], axis =1)

# %%
new_df.head()
# Out:
#    REF_DATE     GEO Characteristics Income, consumption and savings     VALUE
# 0      1999  Canada  All households     Household disposable income  546261.0
# 1      1999  Canada  All households       Compensation of employees  506817.0
# 2      1999  Canada  All households                Net mixed income   97809.0
# 3      1999  Canada  All households        Property income received  111791.0
# 4      1999  Canada  All households      Less: property income paid   36406.0

# %%
df_transpose = new_df.transpose()

# %%
df_transpose.head()
# Out:
#                                                        0      \
# REF_DATE                                                1999
# GEO                                                   Canada
# Characteristics                               All households
# Income, consumption and savings  Household disposable income
# VALUE                                               546261.0
#
#                                                      1                 2      \
# REF_DATE                                              1999              1999
# GEO                                                 Canada            Canada
# Characteristics                             All households    All households
# Income, consumption and savings  Compensation of employees  Net mixed income
# VALUE                                             506817.0           97809.0
#
#                                                     3      \
# REF_DATE                                             1999
# ...

# %%
new_df_characteristics = new_df.pivot(columns = 'REF_DATE' , values = ['GEO', 'Characteristics' ,'Income, consumption and savings' , 'VALUE'])

# %%
new_df_characteristics.head()
# Out:
#              GEO                                               ... VALUE       \
# REF_DATE    1999 2000 2001 2002 2003 2004 2005 2006 2007 2008  ...  2013 2014
# 0         Canada  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN
# 1         Canada  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN
# 2         Canada  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN
# 3         Canada  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN
# 4         Canada  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN
#
#
# REF_DATE 2015 2016 2017 2018 2019 2020 2021 2022
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 96 columns]

# %%
# Specify 'Name' column as index
df_index = new_df.set_index('GEO')

# Transpose the DataFrame
df_transposed = new_df.transpose()

# Display the transposed DataFrame
df_transposed.head()
# Out:
#                                                        0      \
# REF_DATE                                                1999
# GEO                                                   Canada
# Characteristics                               All households
# Income, consumption and savings  Household disposable income
# VALUE                                               546261.0
#
#                                                      1                 2      \
# REF_DATE                                              1999              1999
# GEO                                                 Canada            Canada
# Characteristics                             All households    All households
# Income, consumption and savings  Compensation of employees  Net mixed income
# VALUE                                             506817.0           97809.0
#
#                                                     3      \
# REF_DATE                                             1999
# ...

# %%
filtered_df= new_df.loc[(new_df['GEO'] =='Canada') & (new_df['Characteristics'] =='All households')]

# %%
filtered_df.head()
# Out:
#    REF_DATE     GEO Characteristics Income, consumption and savings     VALUE
# 0      1999  Canada  All households     Household disposable income  546261.0
# 1      1999  Canada  All households       Compensation of employees  506817.0
# 2      1999  Canada  All households                Net mixed income   97809.0
# 3      1999  Canada  All households        Property income received  111791.0
# 4      1999  Canada  All households      Less: property income paid   36406.0

# %%
drop_filtered = filtered_df.drop (columns = ['GEO', 'Characteristics'])

# %%
drop_filtered.head()
# Out:
#    REF_DATE Income, consumption and savings     VALUE
# 0      1999     Household disposable income  546261.0
# 1      1999       Compensation of employees  506817.0
# 2      1999                Net mixed income   97809.0
# 3      1999        Property income received  111791.0
# 4      1999      Less: property income paid   36406.0

# %%
groupby_df = drop_filtered.groupby (by = ['REF_DATE' , 'Income, consumption and savings']).sum()

# %%
groupby_df
# Out:
#                                                         VALUE
# REF_DATE Income, consumption and savings
# 1999     Adjusted household disposable income        779551.0
#          Alcoholic beverages and tobacco              28365.0
#          Change in pension entitlements               36480.0
#          Clothing and footwear                        31517.0
#          Communications                               13007.0
# ...                                                       ...
# 2022     Social transfers in kind (STiK)             943404.0
#          Social transfers in kind (STiK): education  269618.0
#          Social transfers in kind (STiK): health     500156.0
#          Social transfers in kind (STiK): other      174030.0
#          Transport                                   243009.0
#
# [696 rows x 1 columns]
