# %%
#importing the dataset

import pandas as pd
from pathlib import Path
df = pd.read_csv('./consumption data.csv'
            )
df.head()
# Out:
#    REF_DATE     GEO           DGUID Statistics Characteristics  \
# 0      2008  Canada  2016A000011124      Value  All households
# 1      2009  Canada  2016A000011124      Value  All households
# 2      2010  Canada  2016A000011124      Value  All households
# 3      2011  Canada  2016A000011124      Value  All households
# 4      2012  Canada  2016A000011124      Value  All households
#
#   Income, consumption and savings      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0     Household disposable income  Dollars      81      millions          6
# 1     Household disposable income  Dollars      81      millions          6
# 2     Household disposable income  Dollars      81      millions          6
# 3     Household disposable income  Dollars      81      millions          6
# 4     Household disposable income  Dollars      81      millions          6
#
#        VECTOR COORDINATE    VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# ...
