# %% [markdown]
# # Project 1 - Day 1

# %%
# importing the dataset 

import pandas as pd
from pathlib import Path

df = pd.read_csv('./Resources/canada_household_econimic_data.csv')
df.head()
# Out:
#   Income, consumption and savings     2001     2002     2003     2004  \
# 0     Household disposable income  615,286  642,584  663,239  695,238
# 1       Compensation of employees  574,278  596,782  620,600  656,154
# 2                Net mixed income  107,636  111,748  116,533  122,301
# 3        Property income received  116,942  109,346  108,675  113,209
# 4      Less: property income paid   41,204   37,300   39,081   40,156
#
#       2005     2006     2007     2008     2009  ...       2013       2014  \
# 0  721,510  774,375  816,321  862,404  884,783  ...  1,046,791  1,081,654
# 1  692,609  737,321  782,564  818,108  810,556  ...    959,181    996,247
# 2  125,661  131,002  138,842  143,917  144,671  ...    167,712    172,078
# 3  122,970  137,105  153,667  160,013  152,106  ...    175,342    181,876
# 4   43,309   52,632   61,313   63,921   55,559  ...     56,232     55,857
#
#         2015       2016       2017       2018       2019       2020  \
# ...

# %%
df.rename(columns={'Income, consumption and savings':'Segment'},inplace=True)
df.set_index('Segment',inplace = True)
df
# Out:
#                                                        2001     2002     2003  \
# Segment
# Household disposable income                         615,286  642,584  663,239
# Compensation of employees                           574,278  596,782  620,600
# Net mixed income                                    107,636  111,748  116,533
# Property income received                            116,942  109,346  108,675
# Less: property income paid                           41,204   37,300   39,081
# Current transfers received                          145,676  147,574  153,189
# Less: current transfers paid                        288,042  285,566  296,677
# Social transfers in kind (STiK)                     160,186  169,696  178,804
# Social transfers in kind (STiK): education           54,355   56,821   59,163
# Social transfers in kind (STiK): health              73,275   77,820   83,061
# Social transfers in kind (STiK): other               32,556   35,055   36,580
# ...

# %%
df_1 = df.transpose()
df_1
# Out:
# Segment Household disposable income Compensation of employees  \
# 2001                        615,286                   574,278
# 2002                        642,584                   596,782
# 2003                        663,239                   620,600
# 2004                        695,238                   656,154
# 2005                        721,510                   692,609
# 2006                        774,375                   737,321
# 2007                        816,321                   782,564
# 2008                        862,404                   818,108
# 2009                        884,783                   810,556
# 2010                        928,091                   835,940
# 2011                        962,102                   881,146
# 2012                      1,001,254                   921,492
# 2013                      1,046,791                   959,181
# 2014                      1,081,654                   996,247
# ...

# %%
cpi_df = pd.read_csv('./Resources/canada_CPI.csv')
cpi_df.head()
# Out:
#   OBSERVATIONS    Unnamed: 1         Unnamed: 2           Unnamed: 3  \
# 0         date  INDINF_CPI_Q  INDINF_CPI_TRIM_Q  INDINF_CPI_MEDIAN_Q
# 1       1993Q1           2.2                  2                    2
# 2       1993Q2           1.8                1.9                  1.9
# 3       1993Q3           1.8                1.8                  1.7
# 4       1993Q4           1.8                1.8                  1.7
#
#             Unnamed: 4
# 0  INDINF_CPI_COMMON_Q
# 1                  1.8
# 2                  1.7
# 3                  1.4
# 4                  1.5

# %%
cpi_df.columns = cpi_df.iloc[0]

# %%
cpi_df.head()
# Out:
# 0    date  INDINF_CPI_Q  INDINF_CPI_TRIM_Q  INDINF_CPI_MEDIAN_Q  \
# 0    date  INDINF_CPI_Q  INDINF_CPI_TRIM_Q  INDINF_CPI_MEDIAN_Q
# 1  1993Q1           2.2                  2                    2
# 2  1993Q2           1.8                1.9                  1.9
# 3  1993Q3           1.8                1.8                  1.7
# 4  1993Q4           1.8                1.8                  1.7
#
# 0  INDINF_CPI_COMMON_Q
# 0  INDINF_CPI_COMMON_Q
# 1                  1.8
# 2                  1.7
# 3                  1.4
# 4                  1.5

# %%
cpi_df = cpi_df.iloc[1:]
cpi_df.head()
# Out:
# 0    date INDINF_CPI_Q INDINF_CPI_TRIM_Q INDINF_CPI_MEDIAN_Q  \
# 1  1993Q1          2.2                 2                   2
# 2  1993Q2          1.8               1.9                 1.9
# 3  1993Q3          1.8               1.8                 1.7
# 4  1993Q4          1.8               1.8                 1.7
# 5  1994Q1          0.5               1.5                 1.6
#
# 0 INDINF_CPI_COMMON_Q
# 1                 1.8
# 2                 1.7
# 3                 1.4
# 4                 1.5
# 5                 1.3

# %%
import requests
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=CGR.TRT&outputsize=full&apikey=QNUCGT4HIOG7WH50&datatype=csv'
r = requests.get(url)
data = pd.read_csv(url)
data
# Out:
#       timestamp   open   high    low  close  volume
# 0    2024-01-16  28.26  28.51  27.82  28.13   19901
# 1    2023-12-29  26.78  28.80  26.78  28.24   73100
# 2    2023-11-30  24.63  26.88  24.54  26.86   65800
# 3    2023-10-31  24.87  25.30  23.95  24.60   57400
# 4    2023-09-29  26.66  26.76  24.46  24.85   71100
# ..          ...    ...    ...    ...    ...     ...
# 180  2009-01-30  14.17  14.23  12.20  12.50   14438
# 181  2008-12-31  12.95  14.71  12.50  14.38   44873
# 182  2008-11-28  15.24  15.41  11.68  13.73  196516
# 183  2008-10-28  18.75  19.03  14.34  14.43  156889
# 184  2008-09-30  20.88  20.88  18.01  18.87   14158
#
# [185 rows x 6 columns]
